# %%
import matplotlib.pyplot as plt

# %%
x = ['Cold As You','White Horse','Sparks Fly','I Almost Do','Welcome To New York','Ready For It','London Boy','Peace','Champagne Problems','Labyrinth']
y = [.2204,.2175,.2017,.1413,.1391,.1396,.1397,.2334,.4090,.1254]

# %%
plt.plot(x, y)
plt.xlabel('Song Title')
plt.ylabel('Proportion Unique Words')
plt.title('Taylor Swift Lyrical Complexion')
plt.tight_layout()
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(6)
plt.plot(x, y)
